# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceMishra10/PROJECT_1-EDA-ON-HOTEL-BOOKING-ANALYSIS/blob/main/Capstone_Project_1_EDA_Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - EDA - Hotel Booking Analysis.

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name**            - Prince Mishra

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Introduction to the Project - **EDA: Hotel Booking Analysis.**
#
# In the fast-paced and competitive world of hospitality, hotels strive to provide exceptional guest experiences while maximizing their revenue. Achieving this delicate balance requires a profound understanding of customer behavior, booking patterns, and factors influencing bookings and cancellations. To accomplish this, we embark on a data-driven journey known as Exploratory Data Analysis (EDA) - a powerful technique that allows us to derive meaningful insights from raw data without the constraints of preconceived hypotheses.
#
# EDA is the process of exploring and summarizing the characteristics of a dataset to unveil hidden patterns, trends, and relationships. It involves various statistical and visual techniques to gain a preliminary understanding of the data, identify outliers and missing values, and ultimately inform further analysis and decision-making. In the context of hotel booking analysis, EDA provides a fundamental framework to extract actionable knowledge from the dataset and make informed strategic decisions.
#
# The primary objectives of our Hotel Booking Analysis project are as follows:
#
# 1. **Understanding Customer Behavior**: By performing EDA on the hotel booking dataset, we seek to comprehend customer preferences, booking habits, and demographic trends. Insights into these aspects will enable hoteliers to tailor their offerings to better meet customer expectations, resulting in enhanced guest satisfaction and loyalty.
#
# 2. **Identifying Booking Trends and Seasonality**: Exploring the dataset allows us to identify trends and seasonality patterns in hotel bookings. This analysis helps in forecasting demand variations throughout the year, enabling hotel managers to optimize staff scheduling, room availability, and pricing strategies during peak and off-peak periods.
#
# 3. **Analyzing Booking Channels**: The dataset provides information on the different booking channels through which customers make reservations. EDA will help determine the most effective and popular booking channels, allowing hotels to allocate marketing resources efficiently and expand their reach to potential guests.
#
# 4. **Investigating Booking Cancellations**: Booking cancellations can lead to revenue loss and operational inefficiencies. EDA will enable us to identify the reasons for cancellations, assess cancellation rates, and explore factors influencing this behavior. Armed with these insights, hotels can implement measures to minimize cancellations and optimize revenue management.
#
# 5. **Pricing and Revenue Analysis**: By analyzing pricing trends and correlating them with booking volumes, EDA can help identify optimal pricing strategies. This analysis empowers hoteliers to set competitive prices that align with customer demand and maximize revenue.
#
# 6. **Sentiment Analysis of Customer Reviews**: Understanding customer sentiments from their reviews is crucial to improving service quality and guest experiences. EDA allows us to perform sentiment analysis on customer feedback, providing invaluable insights into areas for improvement and enhancing overall guest satisfaction.
#
# Through the rigorous application of EDA techniques on the hotel booking dataset, this project aims to empower hotel management with data-driven decisions that enhance operational efficiency, customer satisfaction, and revenue generation. As we embark on this exploratory journey, we expect to unravel valuable insights that will shape the future of hotel services and elevate guest experiences to new heights.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/PrinceMishra10/PROJECT_1-EDA-ON-HOTEL-BOOKING-ANALYSIS.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business Objectives for Hotel Booking Analysis:
#
# 1. Improve Customer Satisfaction:
# Enhancing customer satisfaction is a fundamental objective for any hotel business. By analyzing customer behavior and preferences through EDA, the hotel can identify ways to personalize services, offer targeted promotions, and optimize amenities to better meet guests' expectations, resulting in higher levels of satisfaction and positive reviews.
#
# 2. Optimize Pricing Strategies:
# Accurate pricing is essential to maximize revenue while remaining competitive. EDA can help the hotel understand price elasticity, identify optimal pricing tiers, and determine the most profitable periods for rate adjustments, ultimately leading to increased revenue and improved profitability.
#
# 3. Reduce Booking Cancellations:
# Booking cancellations can negatively impact hotel revenue and operational efficiency. By identifying the factors influencing cancellations through EDA, the hotel can implement strategies to reduce cancellations, such as offering flexible cancellation policies or targeted promotions to incentivize guests to maintain their bookings.
#
# 4. Enhance Revenue Management:
# Understanding booking trends and seasonal patterns enables the hotel to implement effective revenue management strategies. By adjusting room rates and inventory allocation based on demand fluctuations identified through EDA, the hotel can optimize revenue and profitability throughout the year.
#
# 5. Identify Key Booking Channels:
# Analyzing various booking channels allows the hotel to identify the most effective platforms for reaching potential guests. EDA helps determine the channels that generate the highest booking volumes and revenue, enabling the hotel to allocate marketing budgets efficiently and build strong partnerships with successful booking platforms.
#
# 6. Improve Operational Efficiency:
# Data-driven insights from EDA can highlight areas of inefficiency within the hotel's operations. For example, identifying peak booking periods and seasonal demands can help streamline staff scheduling, inventory management, and other operational processes, leading to cost savings and improved resource allocation.
#
# 7. Enhance Marketing Strategies:
# Customer segmentation analysis through EDA allows the hotel to target specific customer groups with personalized marketing campaigns. By tailoring promotions and offers to different segments, the hotel can attract new customers and foster loyalty among existing ones.
#
#
#
#
# In conclusion, the business objectives of conducting an EDA on hotel booking data are centered around improving customer satisfaction, optimizing pricing and revenue management, reducing cancellations, enhancing operational efficiency, and refining marketing strategies. By embracing data-driven decision-making, hotels can elevate their performance, increase profitability, and maintain a competitive edge in the dynamic hospitality industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import seaborn as sns
import ast

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df_hotel = pd.read_csv('/content/drive/MyDrive/EDA project/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df_hotel.head() #Checking first five rows of the DataFrame.
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#Checking last five rows of the DataFrame.
df_hotel.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df_hotel.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#describing the dataset
df_hotel.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

len(df_hotel[df_hotel.duplicated()])
# Out:
# 31994

# %%
#Checking if the duplicates make sense or not
df_hotel[df_hotel. duplicated()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df_hotel.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values

plt.figure(figsize=(10,6))
sns.displot(
    data=df_hotel.isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.show()

# %% [markdown]
# ##As we can see that the '**Company**' column has so much missing values so we can drop it to make our results better.
# ## We can also fill agents null value with '0' as it is less in number and it is ID of the booking agent.

# %%
#Droping the column 'company'
df_hotel.drop(columns='company',inplace = True)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Our hotel booking dataset encompasses a wide range of information relating to various facets of hotel reservations. This comprehensive dataset comprises crucial details such as the hotel type, categorized into resort or city hotel, as well as precise booking dates, encompassing both the arrival and departure dates. Moreover, it includes valuable insights into the diverse booking channels utilized by guests to make their reservations and the lead time, indicating the duration between the booking date and the actual arrival date.
#
# In addition to these fundamental booking details, the dataset offers a glimpse into the guests themselves, as it contains information about the number of adults, children, and infants associated with each reservation. Furthermore, it comprises vital aspects such as pricing, payment methods employed by guests, and the historical record of cancellations or modifications made to bookings. The dataset also delves into market segmentation, allowing us to understand the diverse customer segments that patronize our hotel.
#
#
# Through a comprehensive analysis of this dataset, our primary objective is to unravel essential booking patterns and discern customer preferences. By thoroughly studying the factors that influence cancellations or modifications to bookings, we can implement proactive measures to reduce such occurrences, ultimately optimizing our hotel's operational efficiency and revenue generation.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df_hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df_hotel.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **hotel**: Type of hotel (Resort Hotel or City Hotel).
# 2. **is_canceled**: Binary variable indicating booking cancellation (1) or not (0).
# 3. **lead_time**: Number of days between booking and arrival.
# 4. **arrival_date_year**: The year of arrival.
# 5. **arrival_date_month**: The month of arrival.
# 6. **arrival_date_week_number**: Week number of the year for arrival date.
# 7. **arrival_date_day_of_month**: Day of the month for arrival date.
# 8. **stays_in_weekend_nights**: Number of weekend nights stayed.
# 9. **stays_in_week_nights**: Number of weekday nights stayed.
# 10. **adults**: Number of adults in the booking.
# 11. **children**: Number of children in the booking.
# 12. **babies**: Number of babies in the booking.
# 13. **meal**: Type of meal booked (e.g., Bed & Breakfast, Half board, Full board, Undefined).
# 14. **country**: Country of origin of the guest.
# 15. **market_segment**: Market segment designation (e.g., Online TA, Offline TA/TO, Groups).
# 16. **distribution_channel**: Booking distribution channel (e.g., Direct, Travel Agents).
# 17. **is_repeated_guest**: Binary variable indicating repeated guest (1) or not (0).
# 18. **previous_cancellations**: Number of previous canceled bookings by the guest.
# 19. **previous_bookings_not_canceled**: Number of previous bookings not canceled by the guest.
# 20. **reserved_room_type**: Code of the reserved room type.
# 21. **assigned_room_type**: Code of the assigned room type.
# 22. **booking_changes**: Number of changes or modifications made to the booking.
# 23. **deposit_type**: Type of deposit made by the guest (e.g., No deposit, Non-refundable, Refundable).
# 24. **agent**: ID of the travel agency that made the booking.
# 25. **company**: ID of the company that made the booking. **#but this column is dropped now.**
# 26. **days_in_waiting_list**: Number of days the booking was in the waiting list before confirmation.
# 27. **customer_type**: Type of booking customer (e.g., Transient, Contract, Group, Transient-Party).
# 28.**adr**: Average Daily Rate, calculated by dividing the total booking revenue by the number of staying nights.
# 29. **required_car_parking_spaces**: Number of car parking spaces requested by the guest.
# 30. **total_of_special_requests**: Number of special requests made by the guest.
# 31. **reservation_status**: Categorical variable indicating the final status of the reservation (e.g., Check-Out, Canceled, No-Show).
# 32. **reservation_status_date**: Date when the reservation status was last updated.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df_hotel.columns:
    print("No. of unique values in", column, "is", "'",df_hotel[column].nunique(),"'", ".")
# Out:
# No. of unique values in hotel is ' 2 ' .
# No. of unique values in is_canceled is ' 2 ' .
# No. of unique values in lead_time is ' 479 ' .
# No. of unique values in arrival_date_year is ' 3 ' .
# No. of unique values in arrival_date_month is ' 12 ' .
# No. of unique values in arrival_date_week_number is ' 53 ' .
# No. of unique values in arrival_date_day_of_month is ' 31 ' .
# No. of unique values in stays_in_weekend_nights is ' 17 ' .
# No. of unique values in stays_in_week_nights is ' 35 ' .
# No. of unique values in adults is ' 14 ' .
# No. of unique values in children is ' 5 ' .
# No. of unique values in babies is ' 5 ' .
# No. of unique values in meal is ' 5 ' .
# No. of unique values in country is ' 177 ' .
# No. of unique values in market_segment is ' 8 ' .
# No. of unique values in distribution_channel is ' 5 ' .
# No. of unique values in is_repeated_guest is ' 2 ' .
# No. of unique values in previous_cancellations is ' 15 ' .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# I have already dropped the 'company' Column so it is one of the wrangling code.

df_hotel['agent'].fillna(value = 0 , inplace = True) #as mentioned earlier filling null values of agent by '0'
print(df_hotel['agent'].isnull().sum()) #checking null values
# Out:
# 0

# %%
#filling null values in country column by 'other'
df_hotel['country'].fillna(value= 'other' , inplace = True)
df_hotel['country'].isnull().sum() #checking null values
# Out:
# 0

# %%
#filling null value in children column by '0' assuming not mentioned have no childrens during stays
df_hotel['children'].fillna(value=0 , inplace=True)
df_hotel['children'].isnull().sum() #checking null values
# Out:
# 0

# %%
#counting the rows wih duplicate values
print(df_hotel.duplicated().value_counts())
# Out:
# False    87389
# True     32001
# dtype: int64

# %%
#as we can see that the count of duplicates are in large number so it can mislead the results so it is better to drop them.
df_hotel.drop_duplicates(inplace=True)
df_hotel.reset_index(drop=True,inplace=True)
df_hotel['new_index'] = df_hotel.index
df_hotel.tail()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 87384  City Hotel            0         23               2017
# 87385  City Hotel            0        102               2017
# 87386  City Hotel            0         34               2017
# 87387  City Hotel            0        109               2017
# 87388  City Hotel            0        205               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 87384             August                        35                         30
# 87385             August                        35                         31
# 87386             August                        35                         31
# 87387             August                        35                         31
# 87388             August                        35                         29
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
# change the data type of agent and children from float to int
df_hotel[['children','agent']]= df_hotel[['children','agent']].astype('int64')
#changing the type of the data in the columns to datetime format
df_hotel['reservation_status_date'] = pd.to_datetime(df_hotel['reservation_status_date'],format = '%Y-%m-%d')

# %%
#adding new columns the data frame as per requirement
df_hotel['total_days_stay']=df_hotel['stays_in_week_nights']+df_hotel['stays_in_weekend_nights']
df_hotel['total_person']=df_hotel['adults']+df_hotel[ 'babies']+df_hotel['children']

#total stay in night
df_hotel['total_stay_at_night'] = df_hotel['stays_in_week_nights']+df_hotel['stays_in_weekend_nights']


#we have created a cloumn for revenue using total stay*adr
df_hotel['revenue'] = df_hotel['total_stay_at_night']*df_hotel['adr']

# %%
df_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87389 entries, 0 to 87388
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87389 non-null  object
#  1   is_canceled                     87389 non-null  int64
#  2   lead_time                       87389 non-null  int64
#  3   arrival_date_year               87389 non-null  int64
#  4   arrival_date_month              87389 non-null  object
#  5   arrival_date_week_number        87389 non-null  int64
#  6   arrival_date_day_of_month       87389 non-null  int64
#  7   stays_in_weekend_nights         87389 non-null  int64
#  8   stays_in_week_nights            87389 non-null  int64
#  9   adults                          87389 non-null  int64
#  10  children                        87389 non-null  int64
#  11  babies                          87389 non-null  int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Data Type Conversion:
# The data types of the 'agent' and 'children' columns were converted from float to integer using the astype('int64') method. This conversion is useful when these columns should be treated as discrete numerical values.
#
# 2. Date Conversion:
# The 'reservation_status_date' column was converted to datetime format using the pd.to_datetime() method. This conversion allows for easier manipulation and analysis of date-related information.
#
# 3. New Columns:
# Two new columns were added to the DataFrame:
# 'total_days_stay': This column represents the total number of days stayed by guests, calculated by summing the 'stays_in_week_nights' and 'stays_in_weekend_nights' columns. It provides valuable insights into the length of guests' stays, considering both weekday and weekend nights.
# 'total_person': This column represents the total number of persons associated with each booking, including adults, babies, and children. It offers insights into the group size and composition of guests for each reservation.
#
# 4. Total Stay in Nights:
# An additional column named 'total_stay_at_night' was created by summing the 'stays_in_week_nights' and 'stays_in_weekend_nights' columns. This column indicates the total number of nights a guest stays at the hotel, combining both weekday and weekend stays.
#
# 5. Revenue Calculation:
# The 'revenue' column was created by calculating the revenue generated from each booking. It was computed by multiplying the 'total_stay_at_night' with the 'adr' (Average Daily Rate). This newly added column provides insights into the revenue generated from each booking.
#
#
# ***Insights:***
#
# The conversion of 'agent' and 'children' columns from float to integer implies that these columns contain discrete numerical values (IDs for the agent and number of children), making them suitable for various numerical operations.
# The 'reservation_status_date' column's conversion to datetime format enables easier temporal analysis, such as finding patterns in reservation statuses over time.
# The newly added columns 'total_days_stay' and 'total_person' offer valuable insights into the length of stays and the composition of guest groups, respectively, which can help hotel management tailor services accordingly.
# The 'total_stay_at_night' column consolidates information about the total number of nights guests stayed, providing a clearer picture of their overall stay duration.
# The 'revenue' column helps assess the revenue generated from each booking, facilitating revenue analysis and strategic decision-making related to pricing and revenue management.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 :
# ####Question: What is the distribution of lead time for hotel bookings in the dataset, and how frequently do different lead time intervals occur?

# %%
# Chart - 1 visualization codeimport matplotlib.pyplot as plt
plt.hist(df_hotel['lead_time'], bins=30)
plt.xlabel('Lead Time')
plt.ylabel('Frequency')
plt.title('Distribution of Lead Time')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ANS:- I chose a histogram for the 'lead_time' variable because it is a continuous numerical variable that represents the number of days between the booking date and the arrival date. A histogram is an appropriate choice for visualizing the distribution of a continuous variable, as it displays the frequency distribution of lead times in intervals (bins).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ANS:- The histogram shows a right-skewed distribution, indicating that many bookings are made closer to the arrival date

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ANS:- The insight suggests that the hotel can incentivize early bookings to avoid last-minute cancellations and better manage room availability. Offering discounts for early bookings can create a positive impact on revenue. However, relying solely on last-minute bookings may lead to decreased revenue due to uncertainty and limited availability.

# %% [markdown]
# #### Chart - 2
# #### Question: What is the distribution of hotel bookings by hotel type (resort hotel and city hotel) in the dataset?

# %%
# Chart - 2 visualization code
bar = df_hotel['hotel'].value_counts()
plt.bar(bar.index,bar.values )
plt.xlabel('Hotel Type')
plt.ylabel('Count')
plt.title('Number of Bookings by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ANS:- I chose a bar chart for visualizing the distribution of hotel bookings by hotel type because it effectively displays the count of bookings for each category (resort hotel and city hotel) in a clear and easy-to-understand manner. The bar chart is suitable for comparing categorical data, making it an appropriate choice to showcase the number of bookings for each hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ANS:- The bar chart shows that City Hotel has a higher number of bookings compared to Resort Hotel.
# Basically it shows that the City hotels are more running than the Resort hotels and the Resort hotels should focus on certain things like Marketing, Location of the Hotel,etc

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ANS:- The insight indicates that City Hotel is more popular among guests, and the positive impact is that the hotel can focus on optimizing resources and amenities based on higher demand. However, it also reveals an opportunity for the Resort Hotel to improve its marketing strategies to attract more bookings and achieve growth.

# %% [markdown]
# #### Chart - 3
# Question:  How does the cancellation rate vary between different hotel types in the dataset?

# %%
# Chart - 3 visualization code
canceled_by_hotel = df_hotel.groupby(['hotel', 'is_canceled']).size().unstack()
canceled_by_hotel.plot(kind='bar', stacked=True)
plt.xlabel('Hotel Type')
plt.ylabel('Count')
plt.title('Bookings Canceled by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ANS:-
# I chose a stacked bar chart for visualizing the number of bookings canceled by hotel type (resort hotel and city hotel) because it effectively represents the distribution of canceled and not-canceled bookings for each category. The stacked bar chart allows us to compare the total count of bookings as well as the proportion of canceled and not-canceled bookings within each hotel type. This type of chart is particularly useful for displaying categorical data with multiple subcategories, making it a suitable choice to illustrate the cancellation status of bookings for different hotel types in a single visual representation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The stacked bar chart shows that City Hotel has a higher number of canceled bookings compared to Resort Hotel as it has higher number of booking as well.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ANS:- The insight suggests that the City Hotel may need to review its booking and cancellation policies or offer incentives to encourage guests to avoid cancellations. This can lead to increased revenue and a positive business impact. On the other hand, the Resort Hotel might explore marketing strategies to attract more bookings and reduce cancellations.

# %% [markdown]
# #### Chart - 4
# Question: What is the distribution of hotel bookings based on the month of arrival, and which months have the highest and lowest booking frequencies?

# %%
# Chart - 4 visualization code
barr= df_hotel['arrival_date_month'].value_counts()
sns.barplot(x=barr.index,y=barr.values,data=df_hotel)


plt.xlabel('Month of Arrival')
plt.ylabel('Count')
plt.title('Number of Bookings by Month of Arrival')
plt.xticks(rotation = 40)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ANS:-
# I chose a bar chart for visualizing the number of bookings based on the month of arrival because it effectively displays the count of bookings for each month in a clear and straightforward manner. The bar chart is suitable for comparing categorical data (months) and allows us to easily observe the booking frequency for each month. It provides a concise representation of the data and makes it easy to identify any variations or patterns in booking activity across different months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ANS:- The bar chart shows the seasonal pattern of bookings throughout the year. As we can see that in the month of August we have most number of bookings and it is a month of Monsoon so it shows that people visit different places in monsoon.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ANS:- The insight allows the hotel to allocate resources and staff based on seasonal demand patterns. By offering seasonal promotions or special events during peak months, the hotel can attract more guests and increase revenue. However, if the hotel does not manage demand effectively during off-peak months, it may experience negative growth due to underutilization of resources.

# %% [markdown]
# #### Chart - 5
# ####Question: What is the distribution of canceled and not-canceled hotel bookings based on customer types, and how does the cancellation behavior vary among different customer segments?

# %%
# Chart - 5 visualization code
canceled_by_customer_type = df_hotel.groupby(['customer_type', 'is_canceled']).size().unstack()
canceled_by_customer_type.plot(kind='bar', stacked=True)
plt.xlabel('Customer Type')
plt.ylabel('Count')
plt.title('Bookings Canceled by Customer Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a stacked bar chart for visualizing the number of bookings canceled by customer type because it effectively represents the distribution of canceled and not-canceled bookings for each customer segment. The stacked bar chart allows for easy comparison of the total count of bookings as well as the relative proportion of canceled and not-canceled bookings within each customer type. This chart type is particularly useful for showcasing categorical data with multiple subcategories, making it suitable for analyzing the cancellation behavior across different customer segments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can identify the customer type -'Transient' with the highest proportion of canceled bookings, So it can help the hotels to update their cancellation policy so that they don't face loss.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. Understanding the cancellation behavior of different customer segments can assist the hotel in several ways:
# Customer Engagement and Retention: By analyzing the cancellation rates for different customer types, the hotel can tailor its customer engagement and retention strategies. For example, the hotel may provide special offers or personalized incentives to reduce cancellations among high-value customer segments, leading to increased loyalty and customer satisfaction.
# Revenue Management: The insights gained from the chart can aid in revenue management efforts. The hotel can optimize pricing strategies and revenue projections based on the observed cancellation patterns for each customer type. This information can help minimize revenue loss due to cancellations and maximize revenue opportunities through targeted pricing strategies.
# Resource Allocation: Understanding the cancellation behavior of various customer segments allows the hotel to allocate resources efficiently. The hotel can focus its efforts on managing bookings and guest services for customer segments that exhibit higher cancellation rates, ensuring better resource allocation and guest experience.

# %% [markdown]
# #### Chart - 6
# Question: What is the trend in monthly revenue for hotel bookings over different years, and are there any noticeable patterns or seasonality in the revenue data?

# %%
# Chart - 6 visualization code

monthly_revenue = df_hotel.groupby(['arrival_date_year', 'arrival_date_month'])['revenue'].sum().reset_index()

# Convert 'revenue' column to numeric data type
monthly_revenue['revenue'] = pd.to_numeric(monthly_revenue['revenue'])

plt.figure(figsize=(12, 6))
sns.lineplot(x='arrival_date_month', y='revenue', hue='arrival_date_year', data=monthly_revenue, marker='o')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.title('Monthly Revenue Trend')
plt.xticks(rotation=45)

# Format y-axis to display actual revenue values
plt.ticklabel_format(style='plain', axis='y')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line chart to show the monthly revenue trend because it is suitable for displaying continuous data over time. It allows us to visualize the revenue fluctuations across months and identify any seasonal patterns or trends effectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By analyzing the chart, the hotel can identify peak months with high revenue and low months when there's a dip in revenue. As we can see that the hotel in the year 2017 have genereted the most and in the month of august.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  The insights gained from this chart can have a positive business impact. The hotel can adjust its pricing strategies, promotional offers, and marketing campaigns based on the seasonal patterns. They can focus their efforts on attracting more guests during low revenue months and implement yield management techniques during peak months to maximize revenue and mostly they should promote more in the summer season.

# %% [markdown]
# #### Chart - 7
#
# Question: What is the variation in cancellation rates across different market segments for hotel bookings, and which market segments have higher or lower cancellation rates?

# %%
# Chart - 7 visualization code
cancellation_by_segment = df_hotel.groupby('market_segment')['is_canceled'].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.barh(cancellation_by_segment['market_segment'], cancellation_by_segment['is_canceled'])
plt.xlabel('Cancellation Rate')
plt.ylabel('Market Segment')
plt.title('Cancellation Rate by Market Segment')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart to compare the cancellation rates across different market segments. This chart type allows us to see the relative proportion of cancellations in each segment while enabling easy comparison between segments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The  bar chart will provide insights into which market segments have a higher cancellation rate. This can help identify segments that might need specific attention and retention strategies like we can see that after the 'undefined' segment the cancellation of 'Online ta' is high in range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can lead to both positive and negative business impacts. If the hotel identifies a particular market segment with a high cancellation rate, they can devise targeted marketing campaigns and incentives to reduce cancellations, leading to positive growth. However, if a segment with high cancellations is not profitable or leads to significant losses, the hotel might consider reevaluating its strategies or repositioning its offerings.

# %% [markdown]
# #### Chart - 8
#
# Question: Is there any relationship between lead time and the number of booking changes for hotel reservations, and how does this relationship manifest in the scatter plot?

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10, 6))
plt.scatter(df_hotel['lead_time'], df_hotel['booking_changes'], alpha=0.5)
plt.xlabel('Lead Time')
plt.ylabel('Booking Changes')
plt.title('Lead Time vs. Booking Changes')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot to visualize the relationship between lead time and the number of booking changes. Scatter plots are effective for displaying the correlation between two continuous variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot can show if there's any correlation between lead time and the number of booking changes. For example, it is revealing whether customers who book well in advance tend to make more changes to their reservations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can have a positive business impact. If a correlation is identified, the hotel can adjust their booking policies and cancellation policies accordingly. For instance, they might consider offering more flexible booking options for guests who plan ahead, leading to higher customer satisfaction.

# %% [markdown]
# #### Chart - 9
#
# Question: What are the top 10 countries with the highest number of hotel bookings, and how do their booking counts compare?

# %%
# Chart - 9 visualization code
country_bookings = df_hotel['country'].value_counts().reset_index().rename(columns={'index': 'Country', 'country': 'Bookings'})

plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='Bookings', data=country_bookings.head(10))
plt.xlabel('Country')
plt.ylabel('Number of Bookings')
plt.title('Top 10 Countries by Bookings')
plt.xticks(rotation=45)

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart to compare the number of bookings from different countries. Bar charts are effective for visualizing categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart will show which countries contribute the most bookings to the hotel. Identifying top booking countries can help the hotel target specific marketing campaigns and tailor services to meet the preferences of these guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  The insights gained from this chart can have a positive business impact. The hotel can allocate marketing resources to target these top booking countries, leading to increased bookings and potential revenue growth.

# %% [markdown]
# #### Chart - 10
# Question: What is the distribution of reservation statuses for hotel bookings, and how do the number of reservations vary across different reservation statuses?

# %%
# Chart - 10 visualization code
reservation_status_counts = df_hotel['reservation_status'].value_counts().reset_index().rename(columns={'index': 'Reservation Status', 'reservation_status': 'Count'})

plt.figure(figsize=(8, 6))
sns.lineplot(x='Reservation Status', y='Count', data=reservation_status_counts, marker='o')
plt.xlabel('Reservation Status')
plt.ylabel('Number of Reservations')
plt.title('Reservation Status Distribution')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line plot for the Reservation Status Distribution because it is effective in showing the trend and variation of the count of reservations for each reservation status. It allows us to visualize how the number of reservations changes over time for each status.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line plot shows the distribution of reservation statuses: 'Check-Out', 'Canceled', and 'No-Show'. It provides insights into the relative frequency of each status, helping the hotel understand the booking patterns and reservation outcomes.
# As we can see that the check-out category has more reservation status from other categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact: The gained insights can have a positive business impact. By understanding the distribution of reservation statuses, the hotel can optimize its operational and marketing strategies. For example, if there is a high number of cancellations, the hotel can implement better cancellation policies or offer incentives to encourage guests to modify their reservations instead of canceling.
#
# Negative Growth: High numbers of 'Canceled' and 'No-Show' reservations can indicate potential revenue losses and operational inefficiencies. If these trends persist, it might be essential for the hotel to address the reasons behind cancellations and no-shows, such as improving communication, offering more flexible booking options, or implementing prepayment policies for certain reservations.
#
# Overall, the chart's insights can help the hotel improve its reservation management, enhance customer experience, and maximize revenue potential. By addressing negative trends and capitalizing on positive trends, the hotel can create a positive business impact and foster long-term growth.

# %% [markdown]
# #### Chart - 11
# Question: What is the average daily rate (ADR) for different room types, and how do the room types compare in terms of their ADR values?

# %%
# Chart - 11 visualization code

average_daily_rate_by_room = df_hotel.groupby('reserved_room_type')['adr'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='reserved_room_type', y='adr', data=average_daily_rate_by_room)
plt.xlabel('Room Type')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate by Room Type')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar plot to compare the average daily rate (ADR) across different room types. It is an effective way to visualize and compare numerical values for categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot shows the average daily rates for different room types. It provides insights into which room types command higher ADRs and which ones are more budget-friendly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact: The insights gained from this chart can have a positive business impact. The hotel can adjust pricing strategies based on the popularity and demand for specific room types. If certain room types have higher ADRs, the hotel can promote them more or tailor packages to attract guests who prefer higher-priced accommodations.
#
# Negative Growth: If certain room types consistently have low ADRs and are less popular among guests, the hotel might need to reevaluate the pricing of those rooms. Additionally, the hotel can explore ways to enhance the appeal of these rooms through renovations or promotional offers to increase their attractiveness to guests.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(df_hotel['total_days_stay'], bins=20, kde=True)
plt.xlabel('Length of Stay (Days)')
plt.ylabel('Frequency')
plt.title('Length of Stay Distribution')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a histogram with KDE to visualize the distribution of the length of stay. It is suitable for displaying the spread and frequency of continuous data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram illustrates the distribution of the length of stay for guests. It provides insights into how long guests typically stay at the hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact: The insights gained from this chart can have a positive business impact. By understanding the length of stay patterns, the hotel can optimize room availability and pricing. For instance, if guests tend to stay longer during certain seasons, the hotel can offer attractive packages for extended stays to attract more guests during those periods.
#
# Negative Growth: If there are extended periods with low occupancy due to short guest stays, the hotel can implement strategies to attract guests for longer durations. Additionally, if the length of stay is highly variable and unpredictable, it can lead to challenges in capacity planning and resource allocation. In such cases, the hotel can explore incentives or promotions to encourage guests to extend their stays.

# %% [markdown]
# #### Chart - 13
# Question: What is the distribution of different customer types in the hotel bookings, and what proportion do they represent in the dataset?

# %%
# Chart - 13 visualization code


plt.figure(figsize=(10,8))
explode = (0.1, 0, 0, 0)
plt.pie(x= df_hotel['customer_type'].value_counts(), labels=df_hotel['customer_type'].unique(), autopct='%1.1f%%',explode=explode)
plt.title('Percentage of Customer Types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pie chart to visualize the percentage distribution of different customer types. A pie chart is effective for displaying proportions and relative sizes of categories in a dataset. It helps viewers quickly grasp the distribution of customer types and their respective contributions to the whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart, we can observe the percentage distribution of customer types in the dataset. Each slice of the pie represents a unique customer type, and the size of each slice corresponds to the proportion of that customer type relative to the total number of customers in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact: The insights gained from the pie chart can help create a positive business impact. By understanding the distribution of customer types, the hotel can tailor its marketing strategies and services to cater to the preferences and needs of different customer segments. For example, if a significant portion of customers belongs to a specific type (e.g., business travelers or leisure tourists), the hotel can offer targeted promotions or amenities to attract and retain these customers.
#
# Negative Growth: There are no specific insights from the pie chart that would lead to negative growth. However, if the distribution of customer types is heavily skewed towards one category, the hotel may need to diversify its customer base to avoid dependency on a single customer segment. A balanced distribution of customer types can mitigate the risks associated with fluctuations in demand from specific customer groups.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap
# What is the correlation between numerical features in the hotel booking dataset, and are there any strong positive or negative relationships between these features?

# %%
# Correlation Heatmap visualization code


#numerical_features = df_hotel[['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'adr', 'total_of_special_requests']] #this code can be used when want categorical data.
plt.figure(figsize=(20,20))
sns.heatmap(df_hotel.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation between Numerical Features')

plt.show()
# Out:
# <ipython-input-40-ce9c146281ab>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_hotel.corr(), annot=True, cmap='coolwarm', fmt='.2f')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a heatmap to visualize the correlation between numerical features. It is an effective way to display the strength and direction of the relationships between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the correlation coefficients between various numerical features. It provides insights into how different variables are related to each other. For example, we can observe if there are any strong positive or negative correlations between features, which can help identify potential relationships between variables
#
# Positive Business Impact: The insights gained from this chart can have a positive business impact. By understanding the correlations between features, the hotel can identify factors that influence revenue and customer satisfaction. For instance, if the number of special requests positively correlates with customer satisfaction, the hotel can focus on enhancing the special request offerings to improve guest experience.
#
# Negative Growth: If there are negative correlations between certain features and customer satisfaction or revenue, the hotel can address these issues to improve overall performance. For example, if lead time negatively correlates with customer satisfaction, the hotel can implement strategies to reduce booking lead time and enhance last-minute booking options to cater to spontaneous travelers.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
selected_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'is_canceled', 'adults', 'previous_cancellations', 'previous_bookings_not_canceled', 'adr']

# Subset the DataFrame with the selected columns
selected_data = df_hotel[selected_columns]

# Plot the pairplot
plt.figure(figsize=(15, 10))
sns.pairplot(selected_data, hue='is_canceled', palette='Set1')
plt.suptitle('Pairplot for Selected Numerical Features', y=1.02)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pairplot for this analysis because it allows us to visualize the relationships and distributions between multiple numerical features simultaneously. It helps us identify patterns and potential correlations between the selected numerical variables in a single plot, making it efficient for exploratory data analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pairplot, we can observe several insights related to the selected numerical features:
#
# Scatter Plots: The scatter plots show the relationships between pairs of numerical features. We can identify if there are linear or nonlinear correlations between different variables. For example, we can determine whether there is a relationship between 'lead_time' and 'adr', which could indicate if early bookings tend to have higher average daily rates.
#
# Diagonal Histograms: The diagonal of the pairplot displays histograms for each individual numerical feature, showing the distribution of data. It helps us understand the spread and shape of each variable. For instance, we can assess the distribution of 'stays_in_weekend_nights' or 'previous_cancellations'.
#
# Positive Business Impact: The insights gained from the pairplot can help create a positive business impact. By understanding the relationships between numerical features, the hotel can identify factors that influence booking patterns and customer behavior. For example, if there is a strong correlation between 'previous_cancellations' and 'is_canceled', the hotel can implement strategies to address potential reasons for cancellations, such as offering flexible cancellation policies or proactive customer service.
#
# Negative Growth: There are no specific insights from the pairplot that would lead to negative growth. However, if any negative correlations are identified between certain features and customer satisfaction or revenue, the hotel can address these issues to improve overall performance. For instance, if there is a negative correlation between 'stays_in_weekend_nights' and 'adr', the hotel can investigate the reasons behind this relationship and consider adjusting pricing or promotional offers during weekends to attract more guests and increase revenue.

# %% [markdown]
# ## Here are some additional charts:

# %%
#1.most preferred channel for booking hotels

group_by_dc = df_hotel['distribution_channel'].value_counts(normalize=True) * 100
channel_percentages = round(group_by_dc, 2)

# Sort the distribution channel labels and data to maintain consistent colors in the chart
channel_data_sorted = channel_percentages.sort_index()
channel_labels_sorted = channel_data_sorted.index.tolist()

plt.figure(figsize=(10, 6))
colors = ['#ffa07a', '#87ceeb', '#98fb98', '#ff69b4']

# Plot the pie chart for distribution channels
wedges, texts, autotexts = plt.pie(x=channel_data_sorted, labels=channel_labels_sorted, colors=colors,
                                  autopct="%.2f%%", pctdistance=0.85, shadow=True, startangle=140)

# Set properties for text labels
for text in texts:
    text.set(size=12, weight='bold')

# Draw circle to create a donut chart
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Create legend
plt.legend(wedges, channel_labels_sorted, loc="upper left", bbox_to_anchor=(0.9, 0.9), title='Distribution Channel')

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

plt.title("Most Preferred Distribution Channels for Booking Hotels", fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# 2. Count the number of repeated guests
repeated_guest_counts = df_hotel['is_repeated_guest'].value_counts()

# Create a count plot of repeated guests
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
ax = sns.countplot(x='is_repeated_guest', data=df_hotel, palette='pastel')

# Set labels and title
plt.title('Count of Repeated Guests', fontsize=16, fontweight='bold')
plt.xlabel('Repeated Guest', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(ticks=[0, 1], labels=['New Guest', 'Repeated Guest'], fontsize=12)

# Annotate the count above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2, p.get_height() + 30),
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='dimgrey')

# Remove top and right spines for better aesthetics
sns.despine()

plt.show()

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the information about the data and the visualizations presented, here are some suggestions for the client to achieve their business objectives:
#
# 1. **Optimize Pricing Strategy:** Analyze the relationship between 'lead_time' and 'adr' using the pairplot. If there is a correlation between early bookings and higher average daily rates, consider implementing dynamic pricing strategies. Offer discounts or incentives to customers who book early to encourage more advance bookings and maximize revenue.
#
# 2. **Enhance Customer Experience:** Utilize the insights from the pie chart showcasing the percentage distribution of customer types. Tailor marketing and services to cater to the preferences of different customer segments. For instance, if a significant portion of customers are leisure tourists, consider offering travel packages or amenities that cater to their interests.
#
# 3. **Address Booking Cancellations:** Investigate the correlation between 'previous_cancellations' and 'is_canceled'. If there is a strong relationship between the two, focus on reducing cancellation rates. Implement flexible cancellation policies, provide clear and transparent booking information, and engage with customers to understand and address their concerns.
#
# 4. **Diversify Customer Base:** Examine the pie chart to ensure a balanced distribution of customer types. Avoid overreliance on a single customer segment to reduce risks associated with fluctuations in demand. Expand marketing efforts to attract customers from different regions and demographics.
#
# 5. **Promote Special Requests:** Explore the impact of 'total_of_special_requests' on revenue and ADR. Encourage guests to make special requests by offering unique experiences, amenities, or personalized services. Increased special requests can lead to higher ADR and overall revenue.
#
# 6. **Target Market Segments with High Revenue:** Analyze the comparing of 'market_segment' with revenue and ADR. Identify market segments that generate higher revenue and tailor marketing strategies to attract more guests from those segments.
#
# 7. **Improve Customer Retention:** Examine the distribution of booking changes. Minimize booking changes by providing accurate information and delivering on customer expectations. Satisfied customers are more likely to return for future bookings and recommend the hotel to others.
#
# 8. **Maximize Weekend Occupancy:** Analyze the relationship between 'stays_in_weekend_nights' and 'adr'. If there is a negative correlation, consider offering weekend-specific promotions or packages to increase weekend occupancy and revenue.
#
# 9. **Utilize Repeated Guests:** Explore the impact of 'is_repeated_guest' on revenue and ADR. Implement loyalty programs or exclusive offers for repeated guests to foster customer loyalty and increase the likelihood of return bookings.
#
# 10. **Monitor Emerging Markets:** Stay updated on the distribution of guests from different countries. Identify emerging markets with increasing bookings and adapt marketing strategies to attract guests from these regions.
#
# Overall, the key recommendations for the client involve optimizing pricing, enhancing guest experience, addressing cancellations, diversifying the customer base, and implementing targeted marketing strategies based on the data insights. By leveraging these recommendations, the hotel can work towards achieving its business objectives, increasing revenue, and improving overall customer satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Conclusion - Exploratory Data Analysis (EDA) for Hotel Bookings Dataset**
#
# In this exploratory data analysis (EDA) project, we analyzed a hotel bookings dataset to gain valuable insights and uncover patterns that can help the hotel business grow. The dataset contains various features related to hotel bookings, customer information, stay details, and revenue.
#
# Throughout the analysis, we performed the following tasks:
#
# 1. **Data Overview:** We started by gaining an understanding of the dataset's structure, including the number of rows, columns, and data types. We observed that the dataset contained (119390, 32) earlier but after cleaning it got 87,389 entries and 36 columns.
#
# 2. **Data Cleaning and Preprocessing:** We checked for missing values and ensured that all data types were appropriate for analysis. There were some missing values which was handled easily.
#
# 3. **Data Visualization:** We utilized various visualization techniques, including bar charts, pie charts, box plots, line plots, and pair plots, to explore different aspects of the data.
#
#    - The bar chart for 'arrival_date_month' provided insights into the distribution of bookings over different months, helping the hotel allocate resources and staff efficiently based on seasonal demand.
#
#    - The pie chart for 'customer_type' showcased the percentage distribution of different customer segments, enabling the hotel to tailor marketing strategies and services to cater to each segment's preferences.
#
#    - The pair plot for selected numerical features allowed us to visualize the relationships and distributions between multiple numerical variables. This provided insights into booking demand, cancellation patterns, pricing, and customer behavior.
#
#
# 4. **Key Findings:**
#
#    - The hotel experiences high booking demand during certain months, indicating a seasonal trend that can influence resource planning and pricing strategies.
#
#    - Understanding customer preferences and tailoring services based on customer types can enhance overall guest experience and improve customer retention.
#
#    - Analyzing market segments and their impact on revenue and pricing can help optimize marketing efforts and target high-value customer groups.
#
#    - Identifying correlations between booking patterns, guest behavior, and cancellation rates can lead to strategies to reduce cancellations and enhance guest satisfaction.
#
#    - Encouraging special requests can potentially lead to increased revenue through additional services and personalized offerings.
#
# 5. **Business Recommendations:**
#
#    - The hotel should implement dynamic pricing strategies, offering discounts or incentives for early bookings to maximize revenue.
#
#    - Personalized marketing efforts should be adopted to cater to different customer segments and enhance customer satisfaction.
#
#    - Strategies to minimize booking cancellations should be implemented, such as offering flexible cancellation policies and proactive customer service.
#
#    - Efforts to diversify the customer base and explore emerging markets can mitigate risks associated with fluctuations in demand.
#
#    - High-revenue market segments should be targeted with tailored marketing strategies to attract more guests from those segments.
#
#    - Customer loyalty programs should be developed to retain repeated guests and foster customer loyalty.
#
#    - The hotel should monitor and adjust pricing strategies to maximize weekend occupancy and revenue.
#
#    - The insights from the EDA should be continuously reviewed and integrated into the hotel's decision-making processes to drive positive business impact and growth.
#
# Overall, the EDA provided valuable insights and recommendations that can help the hotel business thrive, optimize operations, and deliver exceptional guest experiences. By leveraging data-driven insights, the hotel can make informed decisions to enhance its competitive edge in the hospitality industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
